# %% [markdown]
# # Part 3 Transfer Learning Report
#
# Run folder: `resnet50_transfer`
#
# This notebook loads the saved run artifacts, rebuilds pandas tables from the JSON files, and includes cells you can adjust and rerun.

# %%
import json
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\Part3\outputs\external_model_comparison_2026-04-29_082032\resnet50_transfer")
CONFIG_PATH = RUN_DIR / 'config.json'
SUMMARY_PATH = RUN_DIR / 'summary.json'
HISTORY_PATH = RUN_DIR / 'training_history.json'

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Part3.part3_finetuning_external_models import build_data_loaders, denormalize_image

def load_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

config = load_json(CONFIG_PATH)
summary = load_json(SUMMARY_PATH)
history = load_json(HISTORY_PATH)
print(f'Loaded run: {RUN_DIR.name}')
# Out:
# Loaded run: resnet50_transfer

# %% [markdown]
# ## Config And Summary

# %%
config_df = pd.DataFrame([
    {'field': key, 'value': value}
    for key, value in config.items()
])
summary_df = pd.DataFrame([
    {'metric': key, 'value': value}
    for key, value in summary.items()
])
config_df
# Out:
#                            field  \
# 0                      task_name
# 1                     label_mode
# 2                    class_names
# 3                    breed_count
# 4            breed_names_preview
# 5                     model_name
# 6                     batch_size
# 7                    epochs_head
# 8                epochs_finetune
# 9             learning_rate_head
# 10        learning_rate_finetune
# 11              validation_ratio
# 12                    test_ratio
# 13                          seed
# 14           checkpoint_interval
# 15                   num_workers
# 16                  dataset_root
# 17                    output_dir
# 18                        device
# 19                    image_size
# 20            normalization_mean
# 21             normalization_std
# 22               train_transform
# 23                eval_transform
# 24                    train_size
# 25               validation_size
# 26                     test_size
# 27              total_parameters
# 28  initial_trainable_parameters
# 29                    stage_plan
# 30                run_started_at
# 31                optimizer_name
# 32                scheduler_name
# 33                  weight_decay
# 34               label_smoothing
# 35             use_class_weights
# 36                 class_weights
# 37                  weights_name
# 38             transfer_learning
# 39                 backbone_name
# 40                    git_commit
# 41                  git_is_dirty
#
#                                                 value
# 0                               oxford_pet_cat_vs_dog
# 1                                             species
# 2                                          [cat, dog]
# 3                                                  37
# 4   [abyssinian, american bulldog, american pit bu...
# 5                                   resnet50_transfer
# 6                                                  32
# 7                                                   3
# 8                                                  22
# 9                                               0.001
# 10                                             0.0001
# 11                                                0.1
# 12                                                1.0
# 13                                                 42
# 14                                                  1
# 15                                                  0
# 16             C:\Users\emil_\vscode\Assignment1\data
# 17  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 18                                             cuda:0
# 19                                         [224, 224]
# 20                              [0.485, 0.456, 0.406]
# 21                              [0.229, 0.224, 0.225]
# 22  Resize(224x224) -> RandomHorizontalFlip -> Ran...
# 23  Resize(224x224) -> ToTensor -> Normalize(Image...
# 24                                               3312
# 25                                                368
# 26                                               3669
# 27                                           23512130
# 28                                           23512130
# 29  [{'name': 'head', 'epochs': 3, 'learning_rate'...
# 30                                2026-04-29T09:35:57
# 31                                               Adam
# 32                                               none
# 33                                                0.0
# 34                                                0.0
# 35                                              False
# 36                                               None
# 37                     ResNet50_Weights.IMAGENET1K_V2
# 38                                               True
# 39                                           resnet50
# 40           628553f943c9ea725c236fb9c8c21a825aea8d6e
# 41                                              False

# %%
summary_df
# Out:
#                                      metric  \
# 0                                best_epoch
# 1                                best_stage
# 2                          selection_metric
# 3                  best_validation_accuracy
# 4        best_validation_loss_at_best_epoch
# 5                        best_epoch_by_loss
# 6                      best_validation_loss
# 7                time_to_best_model_seconds
# 8               total_training_time_seconds
# 9                average_epoch_time_seconds
# 10                          final_test_loss
# 11                      final_test_accuracy
# 12                      final_test_macro_f1
# 13             test_evaluation_time_seconds
# 14        test_evaluation_images_per_second
# 15   test_evaluation_time_per_image_seconds
# 16        test_evaluation_time_per_image_ms
# 17  test_prediction_collection_time_seconds
# 18            final_test_total_time_seconds
# 19                            stopped_early
# 20                         epochs_completed
# 21                          best_model_path
# 22                     trainable_parameters
# 23                         total_parameters
# 24                            dataset_sizes
# 25                  confusion_matrix_counts
#
#                                                 value
# 0                                                   7
# 1                                            finetune
# 2                                 validation_accuracy
# 3                                                 1.0
# 4                                            0.000768
# 5                                                  14
# 6                                            0.000768
# 7                                          217.398694
# 8                                          816.762731
# 9                                           32.444897
# 10                                           0.009229
# 11                                           0.996184
# 12                                           0.995641
# 13                                          15.271872
# 14                                          240.24559
# 15                                           0.004162
# 16                                           4.162407
# 17                                          15.438909
# 18                                          30.710782
# 19                                              False
# 20                                                 25
# 21  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 22                                           23512130
# 23                                           23512130
# 24   {'train': 3312, 'validation': 368, 'test': 3669}
# 25                            [[1180, 3], [11, 2475]]

# %% [markdown]
# ## Epoch History

# %%
history_df = pd.DataFrame(history)
history_df.index = history_df.index + 1
history_df.index.name = 'epoch'
history_df
# Out:
#        train_loss  train_accuracy  val_loss  val_accuracy  \
# epoch
# 1        0.181217        0.961957  0.059623      1.000000
# 2        0.052026        0.988527  0.035488      1.000000
# 3        0.033395        0.994565  0.022322      1.000000
# 4        0.016273        0.993357  0.011037      0.994565
# 5        0.012736        0.996377  0.022735      0.994565
# 6        0.003811        0.998792  0.010344      0.994565
# 7        0.003548        0.999396  0.003224      1.000000
# 8        0.004611        0.998792  0.003021      0.997283
# 9        0.002068        0.999698  0.003295      1.000000
# 10       0.000483        1.000000  0.002110      1.000000
# 11       0.001689        0.999396  0.003841      0.997283
# 12       0.001053        0.999698  0.001726      1.000000
# 13       0.000663        0.999698  0.000909      1.000000
# 14       0.000154        1.000000  0.000768      1.000000
# 15       0.000051        1.000000  0.001081      1.000000
# 16       0.013545        0.994263  0.013292      0.994565
# 17       0.007923        0.998188  0.013200      0.997283
# 18       0.007588        0.997886  0.014946      0.994565
# 19       0.007616        0.998188  0.011314      0.997283
# 20       0.008476        0.996679  0.024038      0.989130
# 21       0.001616        0.999396  0.013045      0.994565
# 22       0.003652        0.999396  0.003747      0.997283
# 23       0.000461        0.999698  0.003856      0.997283
# 24       0.004845        0.998188  0.017958      0.994565
# 25       0.005696        0.998188  0.011194      0.997283
#
#        epoch_duration_seconds  learning_rate     stage
# epoch
# 1                   25.354295         0.0010      head
# 2                   25.137310         0.0010      head
# 3                   25.191435         0.0010      head
# 4                   31.451423         0.0001  finetune
# 5                   32.333132         0.0001  finetune
# 6                   36.781572         0.0001  finetune
# 7                   38.782121         0.0001  finetune
# 8                   34.537851         0.0001  finetune
# 9                   34.317217         0.0001  finetune
# 10                  32.994893         0.0001  finetune
# 11                  34.092492         0.0001  finetune
# 12                  35.201584         0.0001  finetune
# 13                  35.692704         0.0001  finetune
# 14                  35.060785         0.0001  finetune
# 15                  33.913421         0.0001  finetune
# 16                  32.800578         0.0001  finetune
# 17                  32.247712         0.0001  finetune
# 18                  32.345732         0.0001  finetune
# 19                  33.054488         0.0001  finetune
# 20                  31.832231         0.0001  finetune
# 21                  31.911836         0.0001  finetune
# 22                  31.927252         0.0001  finetune
# 23                  31.528159         0.0001  finetune
# 24                  31.339862         0.0001  finetune
# 25                  31.292340         0.0001  finetune

# %% [markdown]
# ## Metric Curves From JSON

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
history_df[['train_loss', 'val_loss']].plot(ax=axes[0], marker='o', title='Loss')
history_df[['train_accuracy', 'val_accuracy']].plot(ax=axes[1], marker='o', title='Accuracy')
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rebuild The Dataset

# %%
data_bundle = build_data_loaders(
    dataset_root=Path(config['dataset_root']),
    batch_size=config['batch_size'],
    validation_ratio=config['validation_ratio'],
    test_ratio=config['test_ratio'],
    seed=config['seed'],
    num_workers=config.get('num_workers', 0),
)
pd.DataFrame([
    {'split': 'train', 'samples': data_bundle['train_size']},
    {'split': 'validation', 'samples': data_bundle['val_size']},
    {'split': 'test', 'samples': data_bundle['test_size']},
])
# Out:
#         split  samples
# 0       train     3312
# 1  validation      368
# 2        test     3669

# %% [markdown]
# ## Preview A Training Batch

# %%
images, labels = next(iter(data_bundle['train_loader']))
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()
for axis in axes:
    axis.axis('off')
for index in range(min(8, len(images))):
    axes[index].imshow(denormalize_image(images[index]))
    axes[index].set_title(data_bundle['class_names'][int(labels[index])])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saved Artifacts

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'confusion_matrix.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### confusion_matrix.png
# ### correct_predictions.png
# ### incorrect_predictions.png

# %% [markdown]
# ## Re-Run This Experiment

# %%
from argparse import Namespace
from Part3.part3_finetuning_external_models import run_experiment

# Uncomment to rerun into a new folder.
# rerun_args = Namespace(
#     model=config['model_name'],
#     dataset_root=config['dataset_root'],
#     batch_size=config['batch_size'],
#     epochs_head=config['epochs_head'],
#     epochs_finetune=config['epochs_finetune'],
#     learning_rate_head=config['learning_rate_head'],
#     learning_rate_finetune=config['learning_rate_finetune'],
#     validation_ratio=config['validation_ratio'],
#     test_ratio=config['test_ratio'],
#     seed=config['seed'],
#     output_dir=str(RUN_DIR.parent / f'{RUN_DIR.name}_rerun'),
#     checkpoint_interval=config['checkpoint_interval'],
#     num_workers=config.get('num_workers', 0),
# )
# run_experiment(rerun_args)
