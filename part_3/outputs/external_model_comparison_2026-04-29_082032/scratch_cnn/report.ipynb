# %% [markdown]
# # Part 3 Transfer Learning Report
#
# Run folder: `scratch_cnn`
#
# This notebook loads the saved run artifacts, rebuilds pandas tables from the JSON files, and includes cells you can adjust and rerun.

# %%
import json
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\Part3\outputs\external_model_comparison_2026-04-29_082032\scratch_cnn")
CONFIG_PATH = RUN_DIR / 'config.json'
SUMMARY_PATH = RUN_DIR / 'summary.json'
HISTORY_PATH = RUN_DIR / 'training_history.json'

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Part3.part3_finetuning_external_models import build_data_loaders, denormalize_image

def load_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

config = load_json(CONFIG_PATH)
summary = load_json(SUMMARY_PATH)
history = load_json(HISTORY_PATH)
print(f'Loaded run: {RUN_DIR.name}')
# Out:
# Loaded run: scratch_cnn

# %% [markdown]
# ## Config And Summary

# %%
config_df = pd.DataFrame([
    {'field': key, 'value': value}
    for key, value in config.items()
])
summary_df = pd.DataFrame([
    {'metric': key, 'value': value}
    for key, value in summary.items()
])
config_df
# Out:
#                            field  \
# 0                      task_name
# 1                     label_mode
# 2                    class_names
# 3                    breed_count
# 4            breed_names_preview
# 5                     model_name
# 6                     batch_size
# 7                    epochs_head
# 8                epochs_finetune
# 9             learning_rate_head
# 10        learning_rate_finetune
# 11              validation_ratio
# 12                    test_ratio
# 13                          seed
# 14           checkpoint_interval
# 15                   num_workers
# 16                  dataset_root
# 17                    output_dir
# 18                        device
# 19                    image_size
# 20            normalization_mean
# 21             normalization_std
# 22               train_transform
# 23                eval_transform
# 24                    train_size
# 25               validation_size
# 26                     test_size
# 27              total_parameters
# 28  initial_trainable_parameters
# 29                    stage_plan
# 30                run_started_at
# 31                optimizer_name
# 32                scheduler_name
# 33                  weight_decay
# 34               label_smoothing
# 35             use_class_weights
# 36                 class_weights
# 37                  weights_name
# 38             transfer_learning
# 39                 backbone_name
# 40                    git_commit
# 41                  git_is_dirty
#
#                                                 value
# 0                               oxford_pet_cat_vs_dog
# 1                                             species
# 2                                          [cat, dog]
# 3                                                  37
# 4   [abyssinian, american bulldog, american pit bu...
# 5                                         scratch_cnn
# 6                                                  32
# 7                                                   3
# 8                                                  47
# 9                                               0.001
# 10                                             0.0001
# 11                                                0.1
# 12                                                1.0
# 13                                                 42
# 14                                                  1
# 15                                                  0
# 16             C:\Users\emil_\vscode\Assignment1\data
# 17  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 18                                             cuda:0
# 19                                         [224, 224]
# 20                              [0.485, 0.456, 0.406]
# 21                              [0.229, 0.224, 0.225]
# 22  Resize(224x224) -> RandomHorizontalFlip -> Ran...
# 23  Resize(224x224) -> ToTensor -> Normalize(Image...
# 24                                               3312
# 25                                                368
# 26                                               3669
# 27                                             422530
# 28                                             422530
# 29  [{'name': 'scratch_stage_1', 'epochs': 3, 'lea...
# 30                                2026-04-29T08:20:32
# 31                                               Adam
# 32                                               none
# 33                                                0.0
# 34                                                0.0
# 35                                              False
# 36                                               None
# 37                                               None
# 38                                              False
# 39                                        scratch_cnn
# 40           628553f943c9ea725c236fb9c8c21a825aea8d6e
# 41                                              False

# %%
summary_df
# Out:
#                                      metric  \
# 0                                best_epoch
# 1                                best_stage
# 2                          selection_metric
# 3                  best_validation_accuracy
# 4        best_validation_loss_at_best_epoch
# 5                        best_epoch_by_loss
# 6                      best_validation_loss
# 7                time_to_best_model_seconds
# 8               total_training_time_seconds
# 9                average_epoch_time_seconds
# 10                          final_test_loss
# 11                      final_test_accuracy
# 12                      final_test_macro_f1
# 13             test_evaluation_time_seconds
# 14        test_evaluation_images_per_second
# 15   test_evaluation_time_per_image_seconds
# 16        test_evaluation_time_per_image_ms
# 17  test_prediction_collection_time_seconds
# 18            final_test_total_time_seconds
# 19                            stopped_early
# 20                         epochs_completed
# 21                          best_model_path
# 22                     trainable_parameters
# 23                         total_parameters
# 24                            dataset_sizes
# 25                  confusion_matrix_counts
#
#                                                 value
# 0                                                  45
# 1                                     scratch_stage_2
# 2                                 validation_accuracy
# 3                                            0.771739
# 4                                            0.497114
# 5                                                  45
# 6                                            0.497114
# 7                                         1152.580579
# 8                                         1282.577463
# 9                                           25.634027
# 10                                           0.472425
# 11                                           0.770782
# 12                                            0.72083
# 13                                          14.168507
# 14                                         258.954594
# 15                                           0.003862
# 16                                           3.861681
# 17                                          15.086017
# 18                                          29.254525
# 19                                              False
# 20                                                 50
# 21  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 22                                             422530
# 23                                             422530
# 24   {'train': 3312, 'validation': 368, 'test': 3669}
# 25                          [[638, 545], [296, 2190]]

# %% [markdown]
# ## Epoch History

# %%
history_df = pd.DataFrame(history)
history_df.index = history_df.index + 1
history_df.index.name = 'epoch'
history_df
# Out:
#        train_loss  train_accuracy  val_loss  val_accuracy  \
# epoch
# 1        0.622265        0.664553  0.606486      0.684783
# 2        0.608468        0.675121  0.608801      0.668478
# 3        0.606545        0.676329  0.593518      0.701087
# 4        0.592327        0.679046  0.590148      0.703804
# 5        0.583313        0.685085  0.585335      0.703804
# 6        0.583674        0.693237  0.584573      0.695652
# 7        0.574695        0.690519  0.577859      0.709239
# 8        0.572060        0.703200  0.580917      0.706522
# 9        0.569181        0.693539  0.580520      0.711957
# 10       0.564622        0.706522  0.576040      0.698370
# 11       0.562120        0.710749  0.575966      0.717391
# 12       0.560020        0.706522  0.568976      0.717391
# 13       0.558753        0.712258  0.576951      0.660326
# 14       0.557806        0.702899  0.559457      0.701087
# 15       0.558078        0.711957  0.564459      0.698370
# 16       0.552063        0.713466  0.573684      0.706522
# 17       0.546368        0.717693  0.566394      0.703804
# 18       0.545281        0.722524  0.572229      0.692935
# 19       0.543705        0.719807  0.578297      0.690217
# 20       0.541858        0.725242  0.575895      0.706522
# 21       0.542990        0.732186  0.559683      0.706522
# 22       0.538045        0.723430  0.556138      0.717391
# 23       0.536307        0.727657  0.555266      0.711957
# 24       0.532914        0.725242  0.545816      0.714674
# 25       0.530288        0.738527  0.560573      0.722826
# 26       0.526043        0.729469  0.544798      0.703804
# 27       0.532632        0.726147  0.571895      0.733696
# 28       0.524741        0.740036  0.552917      0.698370
# 29       0.526576        0.731582  0.540155      0.701087
# 30       0.512764        0.742754  0.557086      0.728261
# 31       0.521867        0.735809  0.575845      0.736413
# 32       0.516237        0.746377  0.542221      0.722826
# 33       0.511463        0.752717  0.559555      0.717391
# 34       0.503354        0.752114  0.624382      0.717391
# 35       0.500155        0.753925  0.531936      0.733696
# 36       0.502489        0.760568  0.540990      0.736413
# 37       0.500143        0.758152  0.528829      0.725543
# 38       0.502897        0.759058  0.545914      0.722826
# 39       0.488563        0.761473  0.537326      0.733696
# 40       0.484679        0.766304  0.528518      0.725543
# 41       0.490775        0.765700  0.535597      0.728261
# 42       0.491909        0.765399  0.513742      0.725543
# 43       0.477417        0.774155  0.521042      0.744565
# 44       0.472019        0.776268  0.527124      0.744565
# 45       0.475254        0.779589  0.497114      0.771739
# 46       0.480178        0.769928  0.533778      0.763587
# 47       0.477089        0.773249  0.501067      0.744565
# 48       0.463846        0.785326  0.509118      0.750000
# 49       0.459538        0.784118  0.615904      0.652174
# 50       0.464345        0.782911  0.497258      0.758152
#
#        epoch_duration_seconds  learning_rate            stage
# epoch
# 1                   26.324606         0.0010  scratch_stage_1
# 2                   25.861908         0.0010  scratch_stage_1
# 3                   26.125623         0.0010  scratch_stage_1
# 4                   25.631472         0.0001  scratch_stage_2
# 5                   25.735819         0.0001  scratch_stage_2
# 6                   25.776994         0.0001  scratch_stage_2
# 7                   25.079810         0.0001  scratch_stage_2
# 8                   24.796503         0.0001  scratch_stage_2
# 9                   24.880590         0.0001  scratch_stage_2
# 10                  24.844990         0.0001  scratch_stage_2
# 11                  24.788616         0.0001  scratch_stage_2
# 12                  24.753314         0.0001  scratch_stage_2
# 13                  25.220725         0.0001  scratch_stage_2
# 14                  24.705243         0.0001  scratch_stage_2
# 15                  24.968627         0.0001  scratch_stage_2
# 16                  24.770889         0.0001  scratch_stage_2
# 17                  24.948529         0.0001  scratch_stage_2
# 18                  25.551490         0.0001  scratch_stage_2
# 19                  25.546455         0.0001  scratch_stage_2
# 20                  27.746608         0.0001  scratch_stage_2
# 21                  25.625563         0.0001  scratch_stage_2
# 22                  29.971525         0.0001  scratch_stage_2
# 23                  26.398075         0.0001  scratch_stage_2
# 24                  29.497862         0.0001  scratch_stage_2
# 25                  25.209564         0.0001  scratch_stage_2
# 26                  24.762970         0.0001  scratch_stage_2
# 27                  24.906423         0.0001  scratch_stage_2
# 28                  24.630559         0.0001  scratch_stage_2
# 29                  25.228542         0.0001  scratch_stage_2
# 30                  25.599535         0.0001  scratch_stage_2
# 31                  25.903530         0.0001  scratch_stage_2
# 32                  25.437101         0.0001  scratch_stage_2
# 33                  24.987893         0.0001  scratch_stage_2
# 34                  24.909347         0.0001  scratch_stage_2
# 35                  24.894357         0.0001  scratch_stage_2
# 36                  25.320511         0.0001  scratch_stage_2
# 37                  26.496120         0.0001  scratch_stage_2
# 38                  25.095812         0.0001  scratch_stage_2
# 39                  25.200483         0.0001  scratch_stage_2
# 40                  25.572332         0.0001  scratch_stage_2
# 41                  26.247572         0.0001  scratch_stage_2
# 42                  25.116995         0.0001  scratch_stage_2
# 43                  25.248362         0.0001  scratch_stage_2
# 44                  25.669912         0.0001  scratch_stage_2
# 45                  25.781104         0.0001  scratch_stage_2
# 46                  26.220576         0.0001  scratch_stage_2
# 47                  25.677095         0.0001  scratch_stage_2
# 48                  27.059798         0.0001  scratch_stage_2
# 49                  25.479161         0.0001  scratch_stage_2
# 50                  25.493841         0.0001  scratch_stage_2

# %% [markdown]
# ## Metric Curves From JSON

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
history_df[['train_loss', 'val_loss']].plot(ax=axes[0], marker='o', title='Loss')
history_df[['train_accuracy', 'val_accuracy']].plot(ax=axes[1], marker='o', title='Accuracy')
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rebuild The Dataset

# %%
data_bundle = build_data_loaders(
    dataset_root=Path(config['dataset_root']),
    batch_size=config['batch_size'],
    validation_ratio=config['validation_ratio'],
    test_ratio=config['test_ratio'],
    seed=config['seed'],
    num_workers=config.get('num_workers', 0),
)
pd.DataFrame([
    {'split': 'train', 'samples': data_bundle['train_size']},
    {'split': 'validation', 'samples': data_bundle['val_size']},
    {'split': 'test', 'samples': data_bundle['test_size']},
])
# Out:
#         split  samples
# 0       train     3312
# 1  validation      368
# 2        test     3669

# %% [markdown]
# ## Preview A Training Batch

# %%
images, labels = next(iter(data_bundle['train_loader']))
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()
for axis in axes:
    axis.axis('off')
for index in range(min(8, len(images))):
    axes[index].imshow(denormalize_image(images[index]))
    axes[index].set_title(data_bundle['class_names'][int(labels[index])])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saved Artifacts

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'confusion_matrix.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### confusion_matrix.png
# ### correct_predictions.png
# ### incorrect_predictions.png

# %% [markdown]
# ## Re-Run This Experiment

# %%
from argparse import Namespace
from Part3.part3_finetuning_external_models import run_experiment

# Uncomment to rerun into a new folder.
# rerun_args = Namespace(
#     model=config['model_name'],
#     dataset_root=config['dataset_root'],
#     batch_size=config['batch_size'],
#     epochs_head=config['epochs_head'],
#     epochs_finetune=config['epochs_finetune'],
#     learning_rate_head=config['learning_rate_head'],
#     learning_rate_finetune=config['learning_rate_finetune'],
#     validation_ratio=config['validation_ratio'],
#     test_ratio=config['test_ratio'],
#     seed=config['seed'],
#     output_dir=str(RUN_DIR.parent / f'{RUN_DIR.name}_rerun'),
#     checkpoint_interval=config['checkpoint_interval'],
#     num_workers=config.get('num_workers', 0),
# )
# run_experiment(rerun_args)
