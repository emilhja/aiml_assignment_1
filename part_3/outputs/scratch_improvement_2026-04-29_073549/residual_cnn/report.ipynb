# %% [markdown]
# # Part 3 Transfer Learning Report
#
# Run folder: `residual_cnn`
#
# This notebook loads the saved run artifacts, rebuilds pandas tables from the JSON files, and includes cells you can adjust and rerun.

# %%
import json
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\Part3\outputs\scratch_improvement_2026-04-29_073549\residual_cnn")
CONFIG_PATH = RUN_DIR / 'config.json'
SUMMARY_PATH = RUN_DIR / 'summary.json'
HISTORY_PATH = RUN_DIR / 'training_history.json'

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Part3.part3_finetuning_external_models import build_data_loaders, denormalize_image

def load_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

config = load_json(CONFIG_PATH)
summary = load_json(SUMMARY_PATH)
history = load_json(HISTORY_PATH)
print(f'Loaded run: {RUN_DIR.name}')
# Out:
# Loaded run: residual_cnn

# %% [markdown]
# ## Config And Summary

# %%
config_df = pd.DataFrame([
    {'field': key, 'value': value}
    for key, value in config.items()
])
summary_df = pd.DataFrame([
    {'metric': key, 'value': value}
    for key, value in summary.items()
])
config_df
# Out:
#                            field  \
# 0                      task_name
# 1                     label_mode
# 2                    class_names
# 3                    breed_count
# 4            breed_names_preview
# 5                     model_name
# 6                  backbone_name
# 7              transfer_learning
# 8                   weights_name
# 9                   variant_name
# 10                 variant_notes
# 11                    batch_size
# 12                   epochs_head
# 13               epochs_finetune
# 14            learning_rate_head
# 15        learning_rate_finetune
# 16              validation_ratio
# 17                    test_ratio
# 18                          seed
# 19           checkpoint_interval
# 20                   num_workers
# 21                  dataset_root
# 22                    output_dir
# 23                        device
# 24                    image_size
# 25            normalization_mean
# 26             normalization_std
# 27               train_transform
# 28                eval_transform
# 29                    train_size
# 30               validation_size
# 31                     test_size
# 32              total_parameters
# 33  initial_trainable_parameters
# 34                    stage_plan
# 35                run_started_at
# 36                optimizer_name
# 37                scheduler_name
# 38                  weight_decay
# 39               label_smoothing
# 40             use_class_weights
# 41                 class_weights
# 42                    git_commit
# 43                  git_is_dirty
#
#                                                 value
# 0                               oxford_pet_cat_vs_dog
# 1                                             species
# 2                                          [cat, dog]
# 3                                                  37
# 4   [abyssinian, american bulldog, american pit bu...
# 5                                scratch_cnn_improved
# 6                                        residual_cnn
# 7                                               False
# 8                                                None
# 9                                        residual_cnn
# 10        Scratch residual CNN with skip connections.
# 11                                                 32
# 12                                                 25
# 13                                                  0
# 14                                             0.0003
# 15                                                0.0
# 16                                                0.1
# 17                                                1.0
# 18                                                 42
# 19                                                  1
# 20                                                  0
# 21             C:\Users\emil_\vscode\Assignment1\data
# 22  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 23                                             cuda:0
# 24                                         [224, 224]
# 25                              [0.485, 0.456, 0.406]
# 26                              [0.229, 0.224, 0.225]
# 27  Resize(224x224) -> RandomHorizontalFlip -> Ran...
# 28  Resize(224x224) -> ToTensor -> Normalize(Image...
# 29                                               3312
# 30                                                368
# 31                                               3669
# 32                                            2809634
# 33                                            2809634
# 34  [{'name': 'scratch_improved', 'epochs': 25, 'l...
# 35                                2026-04-29T08:02:25
# 36                                              adamw
# 37                                             cosine
# 38                                            0.00005
# 39                                               0.05
# 40                                               True
# 41            [1.352053165435791, 0.6479468941688538]
# 42           1e21224e2364f8efd60b3fd52f0c81d3aebd2865
# 43                                               True

# %%
summary_df
# Out:
#                                      metric  \
# 0                                best_epoch
# 1                                best_stage
# 2                          selection_metric
# 3                  best_validation_accuracy
# 4        best_validation_loss_at_best_epoch
# 5                        best_epoch_by_loss
# 6                      best_validation_loss
# 7                time_to_best_model_seconds
# 8               total_training_time_seconds
# 9                average_epoch_time_seconds
# 10                          final_test_loss
# 11                      final_test_accuracy
# 12                      final_test_macro_f1
# 13             test_evaluation_time_seconds
# 14        test_evaluation_images_per_second
# 15   test_evaluation_time_per_image_seconds
# 16        test_evaluation_time_per_image_ms
# 17  test_prediction_collection_time_seconds
# 18            final_test_total_time_seconds
# 19                            stopped_early
# 20                         epochs_completed
# 21                          best_model_path
# 22                     trainable_parameters
# 23                         total_parameters
# 24                            dataset_sizes
# 25                  confusion_matrix_counts
#
#                                                 value
# 0                                                  18
# 1                                    scratch_improved
# 2                                 validation_accuracy
# 3                                            0.703804
# 4                                             0.64644
# 5                                                  24
# 6                                            0.623015
# 7                                          729.779842
# 8                                         1014.697617
# 9                                           40.514179
# 10                                           0.570166
# 11                                           0.699101
# 12                                           0.667258
# 13                                          17.527135
# 14                                         209.332554
# 15                                           0.004777
# 16                                           4.777088
# 17                                          18.034878
# 18                                          35.562013
# 19                                              False
# 20                                                 25
# 21  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 22                                            2809634
# 23                                            2809634
# 24   {'train': 3312, 'validation': 368, 'test': 3669}
# 25                          [[715, 468], [636, 1850]]

# %% [markdown]
# ## Epoch History

# %%
history_df = pd.DataFrame(history)
history_df.index = history_df.index + 1
history_df.index.name = 'epoch'
history_df
# Out:
#        train_loss  train_accuracy  val_loss  val_accuracy  \
# epoch
# 1        0.699813        0.546196  0.706818      0.581522
# 2        0.690321        0.556159  0.695095      0.505435
# 3        0.677400        0.582126  0.673375      0.540761
# 4        0.672803        0.565217  0.673125      0.548913
# 5        0.672230        0.576389  0.696248      0.529891
# 6        0.668776        0.592995  0.659515      0.603261
# 7        0.658865        0.620471  0.670057      0.605978
# 8        0.654506        0.612319  0.684881      0.627717
# 9        0.655784        0.618056  0.677565      0.538043
# 10       0.654900        0.614432  0.666721      0.538043
# 11       0.653057        0.635568  0.662449      0.652174
# 12       0.644800        0.649457  0.649972      0.608696
# 13       0.640950        0.645531  0.679009      0.614130
# 14       0.636182        0.660930  0.663207      0.578804
# 15       0.636424        0.651570  0.649247      0.649457
# 16       0.627669        0.659420  0.639933      0.608696
# 17       0.621758        0.680556  0.657034      0.665761
# 18       0.608026        0.692633  0.646440      0.703804
# 19       0.602060        0.696256  0.635408      0.649457
# 20       0.595435        0.693841  0.623268      0.673913
# 21       0.592363        0.710145  0.624785      0.652174
# 22       0.582212        0.708937  0.628114      0.695652
# 23       0.573093        0.709843  0.625584      0.668478
# 24       0.575661        0.717995  0.623015      0.701087
# 25       0.574735        0.713164  0.624641      0.692935
#
#        epoch_duration_seconds  learning_rate             stage
# epoch
# 1                   40.699393       0.000300  scratch_improved
# 2                   41.333088       0.000299  scratch_improved
# 3                   42.767169       0.000295  scratch_improved
# 4                   41.321846       0.000289  scratch_improved
# 5                   40.154110       0.000281  scratch_improved
# 6                   39.443986       0.000271  scratch_improved
# 7                   40.970385       0.000259  scratch_improved
# 8                   41.115341       0.000246  scratch_improved
# 9                   39.962890       0.000230  scratch_improved
# 10                  39.503764       0.000214  scratch_improved
# 11                  41.177097       0.000196  scratch_improved
# 12                  39.862066       0.000178  scratch_improved
# 13                  40.545028       0.000159  scratch_improved
# 14                  40.565699       0.000141  scratch_improved
# 15                  41.546976       0.000122  scratch_improved
# 16                  38.060979       0.000104  scratch_improved
# 17                  40.037128       0.000086  scratch_improved
# 18                  39.312288       0.000070  scratch_improved
# 19                  40.450036       0.000054  scratch_improved
# 20                  41.803764       0.000041  scratch_improved
# 21                  41.035408       0.000029  scratch_improved
# 22                  39.861159       0.000019  scratch_improved
# 23                  40.459010       0.000011  scratch_improved
# 24                  40.695539       0.000005  scratch_improved
# 25                  40.170334       0.000001  scratch_improved

# %% [markdown]
# ## Metric Curves From JSON

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
history_df[['train_loss', 'val_loss']].plot(ax=axes[0], marker='o', title='Loss')
history_df[['train_accuracy', 'val_accuracy']].plot(ax=axes[1], marker='o', title='Accuracy')
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rebuild The Dataset

# %%
data_bundle = build_data_loaders(
    dataset_root=Path(config['dataset_root']),
    batch_size=config['batch_size'],
    validation_ratio=config['validation_ratio'],
    test_ratio=config['test_ratio'],
    seed=config['seed'],
    num_workers=config.get('num_workers', 0),
)
pd.DataFrame([
    {'split': 'train', 'samples': data_bundle['train_size']},
    {'split': 'validation', 'samples': data_bundle['val_size']},
    {'split': 'test', 'samples': data_bundle['test_size']},
])
# Out:
#         split  samples
# 0       train     3312
# 1  validation      368
# 2        test     3669

# %% [markdown]
# ## Preview A Training Batch

# %%
images, labels = next(iter(data_bundle['train_loader']))
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()
for axis in axes:
    axis.axis('off')
for index in range(min(8, len(images))):
    axes[index].imshow(denormalize_image(images[index]))
    axes[index].set_title(data_bundle['class_names'][int(labels[index])])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saved Artifacts

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'confusion_matrix.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### confusion_matrix.png
# ### correct_predictions.png
# ### incorrect_predictions.png

# %% [markdown]
# ## Re-Run This Experiment

# %%
from argparse import Namespace
from Part3.part3_finetuning_external_models import run_experiment

# Uncomment to rerun into a new folder.
# rerun_args = Namespace(
#     model=config['model_name'],
#     dataset_root=config['dataset_root'],
#     batch_size=config['batch_size'],
#     epochs_head=config['epochs_head'],
#     epochs_finetune=config['epochs_finetune'],
#     learning_rate_head=config['learning_rate_head'],
#     learning_rate_finetune=config['learning_rate_finetune'],
#     validation_ratio=config['validation_ratio'],
#     test_ratio=config['test_ratio'],
#     seed=config['seed'],
#     output_dir=str(RUN_DIR.parent / f'{RUN_DIR.name}_rerun'),
#     checkpoint_interval=config['checkpoint_interval'],
#     num_workers=config.get('num_workers', 0),
# )
# run_experiment(rerun_args)
