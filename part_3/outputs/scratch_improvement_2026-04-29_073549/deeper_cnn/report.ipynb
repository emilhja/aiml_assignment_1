# %% [markdown]
# # Part 3 Transfer Learning Report
#
# Run folder: `deeper_cnn`
#
# This notebook loads the saved run artifacts, rebuilds pandas tables from the JSON files, and includes cells you can adjust and rerun.

# %%
import json
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\Part3\outputs\scratch_improvement_2026-04-29_073549\deeper_cnn")
CONFIG_PATH = RUN_DIR / 'config.json'
SUMMARY_PATH = RUN_DIR / 'summary.json'
HISTORY_PATH = RUN_DIR / 'training_history.json'

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from Part3.part3_finetuning_external_models import build_data_loaders, denormalize_image

def load_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

config = load_json(CONFIG_PATH)
summary = load_json(SUMMARY_PATH)
history = load_json(HISTORY_PATH)
print(f'Loaded run: {RUN_DIR.name}')
# Out:
# Loaded run: deeper_cnn

# %% [markdown]
# ## Config And Summary

# %%
config_df = pd.DataFrame([
    {'field': key, 'value': value}
    for key, value in config.items()
])
summary_df = pd.DataFrame([
    {'metric': key, 'value': value}
    for key, value in summary.items()
])
config_df
# Out:
#                            field  \
# 0                      task_name
# 1                     label_mode
# 2                    class_names
# 3                    breed_count
# 4            breed_names_preview
# 5                     model_name
# 6                  backbone_name
# 7              transfer_learning
# 8                   weights_name
# 9                   variant_name
# 10                 variant_notes
# 11                    batch_size
# 12                   epochs_head
# 13               epochs_finetune
# 14            learning_rate_head
# 15        learning_rate_finetune
# 16              validation_ratio
# 17                    test_ratio
# 18                          seed
# 19           checkpoint_interval
# 20                   num_workers
# 21                  dataset_root
# 22                    output_dir
# 23                        device
# 24                    image_size
# 25            normalization_mean
# 26             normalization_std
# 27               train_transform
# 28                eval_transform
# 29                    train_size
# 30               validation_size
# 31                     test_size
# 32              total_parameters
# 33  initial_trainable_parameters
# 34                    stage_plan
# 35                run_started_at
# 36                optimizer_name
# 37                scheduler_name
# 38                  weight_decay
# 39               label_smoothing
# 40             use_class_weights
# 41                 class_weights
# 42                    git_commit
# 43                  git_is_dirty
#
#                                                 value
# 0                               oxford_pet_cat_vs_dog
# 1                                             species
# 2                                          [cat, dog]
# 3                                                  37
# 4   [abyssinian, american bulldog, american pit bu...
# 5                                scratch_cnn_improved
# 6                                          deeper_cnn
# 7                                               False
# 8                                                None
# 9                                          deeper_cnn
# 10      Higher-capacity CNN with class-weighted loss.
# 11                                                 32
# 12                                                 25
# 13                                                  0
# 14                                             0.0003
# 15                                                0.0
# 16                                                0.1
# 17                                                1.0
# 18                                                 42
# 19                                                  1
# 20                                                  0
# 21             C:\Users\emil_\vscode\Assignment1\data
# 22  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 23                                             cuda:0
# 24                                         [224, 224]
# 25                              [0.485, 0.456, 0.406]
# 26                              [0.229, 0.224, 0.225]
# 27  Resize(224x224) -> RandomHorizontalFlip -> Ran...
# 28  Resize(224x224) -> ToTensor -> Normalize(Image...
# 29                                               3312
# 30                                                368
# 31                                               3669
# 32                                            3485666
# 33                                            3485666
# 34  [{'name': 'scratch_improved', 'epochs': 25, 'l...
# 35                                2026-04-29T07:48:31
# 36                                              adamw
# 37                                             cosine
# 38                                             0.0001
# 39                                               0.05
# 40                                               True
# 41            [1.352053165435791, 0.6479468941688538]
# 42           1e21224e2364f8efd60b3fd52f0c81d3aebd2865
# 43                                               True

# %%
summary_df
# Out:
#                                      metric  \
# 0                                best_epoch
# 1                                best_stage
# 2                          selection_metric
# 3                  best_validation_accuracy
# 4        best_validation_loss_at_best_epoch
# 5                        best_epoch_by_loss
# 6                      best_validation_loss
# 7                time_to_best_model_seconds
# 8               total_training_time_seconds
# 9                average_epoch_time_seconds
# 10                          final_test_loss
# 11                      final_test_accuracy
# 12                      final_test_macro_f1
# 13             test_evaluation_time_seconds
# 14        test_evaluation_images_per_second
# 15   test_evaluation_time_per_image_seconds
# 16        test_evaluation_time_per_image_ms
# 17  test_prediction_collection_time_seconds
# 18            final_test_total_time_seconds
# 19                            stopped_early
# 20                         epochs_completed
# 21                          best_model_path
# 22                     trainable_parameters
# 23                         total_parameters
# 24                            dataset_sizes
# 25                  confusion_matrix_counts
#
#                                                 value
# 0                                                  23
# 1                                    scratch_improved
# 2                                 validation_accuracy
# 3                                            0.880435
# 4                                            0.380906
# 5                                                  23
# 6                                            0.380906
# 7                                          705.138788
# 8                                          768.402957
# 9                                           30.655739
# 10                                           0.278006
# 11                                           0.896975
# 12                                           0.884611
# 13                                          15.764753
# 14                                         232.734385
# 15                                           0.004297
# 16                                           4.296744
# 17                                          16.949309
# 18                                          32.714062
# 19                                              False
# 20                                                 25
# 21  C:\Users\emil_\vscode\Assignment1\Part3\output...
# 22                                            3485666
# 23                                            3485666
# 24   {'train': 3312, 'validation': 368, 'test': 3669}
# 25                         [[1045, 138], [240, 2246]]

# %% [markdown]
# ## Epoch History

# %%
history_df = pd.DataFrame(history)
history_df.index = history_df.index + 1
history_df.index.name = 'epoch'
history_df
# Out:
#        train_loss  train_accuracy  val_loss  val_accuracy  \
# epoch
# 1        0.692252        0.541969  0.688592      0.551630
# 2        0.671789        0.573973  0.691043      0.649457
# 3        0.662932        0.614130  0.684881      0.500000
# 4        0.658693        0.608696  0.658221      0.627717
# 5        0.639216        0.657005  0.688518      0.665761
# 6        0.636443        0.659722  0.683412      0.690217
# 7        0.618829        0.682669  0.670471      0.698370
# 8        0.597302        0.711353  0.601014      0.752717
# 9        0.586866        0.728865  0.789983      0.407609
# 10       0.566380        0.743056  0.585410      0.690217
# 11       0.540931        0.755737  0.661543      0.603261
# 12       0.522305        0.772947  0.598725      0.793478
# 13       0.500992        0.794384  0.526107      0.812500
# 14       0.487737        0.800423  0.615192      0.804348
# 15       0.461999        0.819143  0.519000      0.755435
# 16       0.453413        0.834541  0.462489      0.828804
# 17       0.422726        0.842693  0.453958      0.850543
# 18       0.401892        0.850543  0.443554      0.809783
# 19       0.391115        0.864432  0.478283      0.782609
# 20       0.375718        0.872886  0.404158      0.858696
# 21       0.360518        0.877415  0.390969      0.853261
# 22       0.352789        0.883756  0.395249      0.845109
# 23       0.338738        0.892814  0.380906      0.880435
# 24       0.344532        0.891606  0.387276      0.864130
# 25       0.334847        0.894022  0.384869      0.875000
#
#        epoch_duration_seconds  learning_rate             stage
# epoch
# 1                   29.548302       0.000300  scratch_improved
# 2                   29.433391       0.000299  scratch_improved
# 3                   28.015776       0.000295  scratch_improved
# 4                   27.713003       0.000289  scratch_improved
# 5                   28.350450       0.000281  scratch_improved
# 6                   28.471670       0.000271  scratch_improved
# 7                   27.985742       0.000259  scratch_improved
# 8                   28.490974       0.000246  scratch_improved
# 9                   29.600408       0.000230  scratch_improved
# 10                  29.156636       0.000214  scratch_improved
# 11                  34.138675       0.000196  scratch_improved
# 12                  33.546470       0.000178  scratch_improved
# 13                  36.015248       0.000159  scratch_improved
# 14                  28.744978       0.000141  scratch_improved
# 15                  29.629896       0.000122  scratch_improved
# 16                  30.279627       0.000104  scratch_improved
# 17                  34.042944       0.000086  scratch_improved
# 18                  32.218126       0.000070  scratch_improved
# 19                  33.673792       0.000054  scratch_improved
# 20                  30.699103       0.000041  scratch_improved
# 21                  30.825789       0.000029  scratch_improved
# 22                  31.522507       0.000019  scratch_improved
# 23                  31.187097       0.000011  scratch_improved
# 24                  31.699712       0.000005  scratch_improved
# 25                  31.403160       0.000001  scratch_improved

# %% [markdown]
# ## Metric Curves From JSON

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
history_df[['train_loss', 'val_loss']].plot(ax=axes[0], marker='o', title='Loss')
history_df[['train_accuracy', 'val_accuracy']].plot(ax=axes[1], marker='o', title='Accuracy')
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rebuild The Dataset

# %%
data_bundle = build_data_loaders(
    dataset_root=Path(config['dataset_root']),
    batch_size=config['batch_size'],
    validation_ratio=config['validation_ratio'],
    test_ratio=config['test_ratio'],
    seed=config['seed'],
    num_workers=config.get('num_workers', 0),
)
pd.DataFrame([
    {'split': 'train', 'samples': data_bundle['train_size']},
    {'split': 'validation', 'samples': data_bundle['val_size']},
    {'split': 'test', 'samples': data_bundle['test_size']},
])
# Out:
#         split  samples
# 0       train     3312
# 1  validation      368
# 2        test     3669

# %% [markdown]
# ## Preview A Training Batch

# %%
images, labels = next(iter(data_bundle['train_loader']))
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()
for axis in axes:
    axis.axis('off')
for index in range(min(8, len(images))):
    axes[index].imshow(denormalize_image(images[index]))
    axes[index].set_title(data_bundle['class_names'][int(labels[index])])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saved Artifacts

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'confusion_matrix.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### confusion_matrix.png
# ### correct_predictions.png
# ### incorrect_predictions.png

# %% [markdown]
# ## Re-Run This Experiment

# %%
from argparse import Namespace
from Part3.part3_finetuning_external_models import run_experiment

# Uncomment to rerun into a new folder.
# rerun_args = Namespace(
#     model=config['model_name'],
#     dataset_root=config['dataset_root'],
#     batch_size=config['batch_size'],
#     epochs_head=config['epochs_head'],
#     epochs_finetune=config['epochs_finetune'],
#     learning_rate_head=config['learning_rate_head'],
#     learning_rate_finetune=config['learning_rate_finetune'],
#     validation_ratio=config['validation_ratio'],
#     test_ratio=config['test_ratio'],
#     seed=config['seed'],
#     output_dir=str(RUN_DIR.parent / f'{RUN_DIR.name}_rerun'),
#     checkpoint_interval=config['checkpoint_interval'],
#     num_workers=config.get('num_workers', 0),
# )
# run_experiment(rerun_args)
