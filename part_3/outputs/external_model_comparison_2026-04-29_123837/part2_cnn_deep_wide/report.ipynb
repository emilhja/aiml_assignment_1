# %% [markdown]
# # Part 3 Transfer Learning Report
#
# Run folder: `part2_cnn_deep_wide`
#
# This notebook loads the saved run artifacts, rebuilds pandas tables from the JSON files, and includes cells you can adjust and rerun.

# %%
import json
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import pandas as pd
import torch
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_3\outputs\external_model_comparison_2026-04-29_123837\part2_cnn_deep_wide")
CONFIG_PATH = RUN_DIR / 'config.json'
SUMMARY_PATH = RUN_DIR / 'summary.json'
HISTORY_PATH = RUN_DIR / 'training_history.json'

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

from part_3.part3_finetuning_external_models import build_data_loaders, denormalize_image

def load_json(path):
    return json.loads(Path(path).read_text(encoding='utf-8'))

config = load_json(CONFIG_PATH)
summary = load_json(SUMMARY_PATH)
history = load_json(HISTORY_PATH)
print(f'Loaded run: {RUN_DIR.name}')
# Out:
# Loaded run: part2_cnn_deep_wide

# %% [markdown]
# ## Config And Summary

# %%
config_df = pd.DataFrame([
    {'field': key, 'value': value}
    for key, value in config.items()
])
summary_df = pd.DataFrame([
    {'metric': key, 'value': value}
    for key, value in summary.items()
])
config_df
# Out:
#                            field  \
# 0                      task_name
# 1                     label_mode
# 2                    class_names
# 3                    breed_count
# 4            breed_names_preview
# 5                     model_name
# 6                     batch_size
# 7                    epochs_head
# 8                epochs_finetune
# 9             learning_rate_head
# 10        learning_rate_finetune
# 11              validation_ratio
# 12                    test_ratio
# 13                          seed
# 14           checkpoint_interval
# 15                   num_workers
# 16                  dataset_root
# 17                    output_dir
# 18                        device
# 19                    image_size
# 20            normalization_mean
# 21             normalization_std
# 22               train_transform
# 23                eval_transform
# 24                    train_size
# 25               validation_size
# 26                     test_size
# 27              total_parameters
# 28  initial_trainable_parameters
# 29                    stage_plan
# 30                run_started_at
# 31                optimizer_name
# 32                scheduler_name
# 33                  weight_decay
# 34               label_smoothing
# 35             use_class_weights
# 36                 class_weights
# 37                  weights_name
# 38             transfer_learning
# 39                 backbone_name
# 40            part2_source_model
# 41                 variant_notes
# 42                    git_commit
# 43                  git_is_dirty
#
#                                                 value
# 0                               oxford_pet_cat_vs_dog
# 1                                             species
# 2                                          [cat, dog]
# 3                                                  37
# 4   [abyssinian, american bulldog, american pit bu...
# 5                                 part2_cnn_deep_wide
# 6                                                  32
# 7                                                  40
# 8                                                   0
# 9                                               0.001
# 10                                             0.0001
# 11                                                0.1
# 12                                                0.1
# 13                                                 42
# 14                                                  1
# 15                                                  0
# 16             C:\Users\emil_\vscode\Assignment1\data
# 17  C:\Users\emil_\vscode\Assignment1\part_3\outpu...
# 18                                             cuda:0
# 19                                         [224, 224]
# 20                              [0.485, 0.456, 0.406]
# 21                              [0.229, 0.224, 0.225]
# 22  Resize(224x224) -> RandomHorizontalFlip -> Ran...
# 23  Resize(224x224) -> ToTensor -> Normalize(Image...
# 24                                               3312
# 25                                                368
# 26                                                367
# 27                                             388930
# 28                                             388930
# 29  [{'name': 'part2_cnn_deep_wide', 'epochs': 40,...
# 30                                2026-04-29T12:38:37
# 31                                               Adam
# 32                                               none
# 33                                                0.0
# 34                                                0.0
# 35                                              False
# 36                                               None
# 37                                               None
# 38                                              False
# 39                                part2_cnn_deep_wide
# 40                                      cnn_deep_wide
# 41  Part 2 best CNN architecture adapted from MNIS...
# 42           1d7b1de66eb0b524310f713d39611da232143516
# 43                                               True

# %%
summary_df
# Out:
#                                      metric  \
# 0                                best_epoch
# 1                                best_stage
# 2                          selection_metric
# 3                  best_validation_accuracy
# 4        best_validation_loss_at_best_epoch
# 5                        best_epoch_by_loss
# 6                      best_validation_loss
# 7                time_to_best_model_seconds
# 8               total_training_time_seconds
# 9                average_epoch_time_seconds
# 10                          final_test_loss
# 11                      final_test_accuracy
# 12                      final_test_macro_f1
# 13             test_evaluation_time_seconds
# 14        test_evaluation_images_per_second
# 15   test_evaluation_time_per_image_seconds
# 16        test_evaluation_time_per_image_ms
# 17  test_prediction_collection_time_seconds
# 18            final_test_total_time_seconds
# 19                            stopped_early
# 20                         epochs_completed
# 21                          best_model_path
# 22                     trainable_parameters
# 23                         total_parameters
# 24                            dataset_sizes
# 25                  confusion_matrix_counts
#
#                                                 value
# 0                                                  33
# 1                                 part2_cnn_deep_wide
# 2                                 validation_accuracy
# 3                                            0.921196
# 4                                            0.261696
# 5                                                  40
# 6                                            0.236549
# 7                                          846.185862
# 8                                         1027.159257
# 9                                           25.665224
# 10                                           0.292536
# 11                                           0.871935
# 12                                           0.854199
# 13                                           1.429374
# 14                                         256.755791
# 15                                           0.003895
# 16                                           3.894751
# 17                                           1.416207
# 18                                            2.84558
# 19                                              False
# 20                                                 40
# 21  C:\Users\emil_\vscode\Assignment1\part_3\outpu...
# 22                                             388930
# 23                                             388930
# 24    {'train': 3312, 'validation': 368, 'test': 367}
# 25                              [[96, 28], [19, 224]]

# %% [markdown]
# ## Epoch History

# %%
history_df = pd.DataFrame(history)
history_df.index = history_df.index + 1
history_df.index.name = 'epoch'
history_df
# Out:
#        train_loss  train_accuracy  val_loss  val_accuracy  \
# epoch
# 1        0.628966        0.669988  0.637086      0.687500
# 2        0.616866        0.676027  0.618612      0.687500
# 3        0.589822        0.676630  0.554182      0.701087
# 4        0.567315        0.705918  0.528553      0.722826
# 5        0.554560        0.714070  0.502656      0.744565
# 6        0.532238        0.739734  0.533878      0.679348
# 7        0.531275        0.750302  0.486843      0.755435
# 8        0.516041        0.743659  0.468153      0.771739
# 9        0.508588        0.759360  0.452836      0.782609
# 10       0.495368        0.761473  0.422192      0.817935
# 11       0.484598        0.779287  0.444295      0.798913
# 12       0.468548        0.786534  0.422846      0.807065
# 13       0.455961        0.784420  0.406831      0.801630
# 14       0.449889        0.789855  0.444781      0.798913
# 15       0.436491        0.798611  0.368192      0.858696
# 16       0.421784        0.814010  0.378271      0.831522
# 17       0.420159        0.810085  0.354109      0.855978
# 18       0.410678        0.812802  0.368330      0.855978
# 19       0.389545        0.831220  0.358112      0.828804
# 20       0.395939        0.826691  0.330846      0.853261
# 21       0.362461        0.843599  0.316740      0.869565
# 22       0.362911        0.838164  0.327029      0.861413
# 23       0.346941        0.855676  0.321657      0.858696
# 24       0.332897        0.859903  0.299582      0.883152
# 25       0.329547        0.857186  0.304808      0.875000
# 26       0.309523        0.868357  0.291387      0.875000
# 27       0.303705        0.870773  0.271454      0.896739
# 28       0.291209        0.879831  0.263021      0.883152
# 29       0.282057        0.882246  0.250958      0.902174
# 30       0.276263        0.878925  0.257500      0.902174
# 31       0.265818        0.886171  0.250773      0.902174
# 32       0.264794        0.892210  0.270719      0.896739
# 33       0.247335        0.899155  0.261696      0.921196
# 34       0.247268        0.897947  0.245161      0.899457
# 35       0.233511        0.903684  0.254785      0.910326
# 36       0.221387        0.910326  0.295224      0.866848
# 37       0.227943        0.903684  0.249617      0.907609
# 38       0.228672        0.905193  0.259267      0.896739
# 39       0.207979        0.917874  0.345991      0.853261
# 40       0.207746        0.912440  0.236549      0.915761
#
#        epoch_duration_seconds  learning_rate                stage
# epoch
# 1                   26.101260          0.001  part2_cnn_deep_wide
# 2                   26.236457          0.001  part2_cnn_deep_wide
# 3                   26.056499          0.001  part2_cnn_deep_wide
# 4                   25.895111          0.001  part2_cnn_deep_wide
# 5                   25.675333          0.001  part2_cnn_deep_wide
# 6                   25.336415          0.001  part2_cnn_deep_wide
# 7                   25.011959          0.001  part2_cnn_deep_wide
# 8                   25.738258          0.001  part2_cnn_deep_wide
# 9                   27.102072          0.001  part2_cnn_deep_wide
# 10                  27.307033          0.001  part2_cnn_deep_wide
# 11                  25.711532          0.001  part2_cnn_deep_wide
# 12                  24.898040          0.001  part2_cnn_deep_wide
# 13                  25.809193          0.001  part2_cnn_deep_wide
# 14                  25.393938          0.001  part2_cnn_deep_wide
# 15                  25.427518          0.001  part2_cnn_deep_wide
# 16                  24.771683          0.001  part2_cnn_deep_wide
# 17                  24.971170          0.001  part2_cnn_deep_wide
# 18                  24.630025          0.001  part2_cnn_deep_wide
# 19                  24.332122          0.001  part2_cnn_deep_wide
# 20                  24.402698          0.001  part2_cnn_deep_wide
# 21                  24.415516          0.001  part2_cnn_deep_wide
# 22                  24.474991          0.001  part2_cnn_deep_wide
# 23                  24.404699          0.001  part2_cnn_deep_wide
# 24                  26.676478          0.001  part2_cnn_deep_wide
# 25                  25.564935          0.001  part2_cnn_deep_wide
# 26                  25.443215          0.001  part2_cnn_deep_wide
# 27                  29.010973          0.001  part2_cnn_deep_wide
# 28                  24.920036          0.001  part2_cnn_deep_wide
# 29                  24.999182          0.001  part2_cnn_deep_wide
# 30                  25.924428          0.001  part2_cnn_deep_wide
# 31                  26.627439          0.001  part2_cnn_deep_wide
# 32                  26.547365          0.001  part2_cnn_deep_wide
# 33                  25.890279          0.001  part2_cnn_deep_wide
# 34                  25.635260          0.001  part2_cnn_deep_wide
# 35                  25.634387          0.001  part2_cnn_deep_wide
# 36                  26.268286          0.001  part2_cnn_deep_wide
# 37                  28.676112          0.001  part2_cnn_deep_wide
# 38                  25.435400          0.001  part2_cnn_deep_wide
# 39                  24.519068          0.001  part2_cnn_deep_wide
# 40                  24.732589          0.001  part2_cnn_deep_wide

# %% [markdown]
# ## Metric Curves From JSON

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
history_df[['train_loss', 'val_loss']].plot(ax=axes[0], marker='o', title='Loss')
history_df[['train_accuracy', 'val_accuracy']].plot(ax=axes[1], marker='o', title='Accuracy')
axes[0].grid(True, alpha=0.3)
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Rebuild The Dataset

# %%
data_bundle = build_data_loaders(
    dataset_root=Path(config['dataset_root']),
    batch_size=config['batch_size'],
    validation_ratio=config['validation_ratio'],
    test_ratio=config['test_ratio'],
    seed=config['seed'],
    num_workers=config.get('num_workers', 0),
)
pd.DataFrame([
    {'split': 'train', 'samples': data_bundle['train_size']},
    {'split': 'validation', 'samples': data_bundle['val_size']},
    {'split': 'test', 'samples': data_bundle['test_size']},
])
# Out:
#         split  samples
# 0       train     3312
# 1  validation      368
# 2        test      367

# %% [markdown]
# ## Preview A Training Batch

# %%
images, labels = next(iter(data_bundle['train_loader']))
fig, axes = plt.subplots(2, 4, figsize=(12, 6))
axes = axes.flatten()
for axis in axes:
    axis.axis('off')
for index in range(min(8, len(images))):
    axes[index].imshow(denormalize_image(images[index]))
    axes[index].set_title(data_bundle['class_names'][int(labels[index])])
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Saved Artifacts

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'confusion_matrix.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### confusion_matrix.png
# ### correct_predictions.png
# ### incorrect_predictions.png

# %% [markdown]
# ## Re-Run This Experiment

# %%
from argparse import Namespace
from part_3.part3_finetuning_external_models import run_experiment

# Uncomment to rerun into a new folder.
# rerun_args = Namespace(
#     model=config['model_name'],
#     dataset_root=config['dataset_root'],
#     batch_size=config['batch_size'],
#     epochs_head=config['epochs_head'],
#     epochs_finetune=config['epochs_finetune'],
#     learning_rate_head=config['learning_rate_head'],
#     learning_rate_finetune=config['learning_rate_finetune'],
#     validation_ratio=config['validation_ratio'],
#     test_ratio=config['test_ratio'],
#     seed=config['seed'],
#     output_dir=str(RUN_DIR.parent / f'{RUN_DIR.name}_rerun'),
#     checkpoint_interval=config['checkpoint_interval'],
#     num_workers=config.get('num_workers', 0),
# )
# run_experiment(rerun_args)
