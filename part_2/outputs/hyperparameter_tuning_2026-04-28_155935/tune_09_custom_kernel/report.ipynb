# %% [markdown]
# # Experiment Report
#
# Run folder: `tune_09_custom_kernel`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\hyperparameter_tuning_2026-04-28_155935\tune_09_custom_kernel")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: tune_09_custom_kernel

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0001,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_09_custom_kernel',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_medium_custom_kernel',
#  'conv_channels': [24, 48],
#  'kernel_size': 5,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 128,
#  'activation': 'ReLU',
#  'dropout': 0.1,
#  'batch_norm': True,
#  'trainable_parameters': 332090,
#  'num_conv_layers': 2}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 7,
#  'best_validation_loss': 0.032994956707271435,
#  'best_validation_accuracy': 0.9908333333333333,
#  'time_to_best_model_seconds': 55.7635775000017,
#  'total_training_time_seconds': 57.11742950000189,
#  'average_epoch_time_seconds': 7.954617971428628,
#  'final_test_loss': 0.025941139761632804,
#  'final_test_accuracy': 0.9921,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_09_custom_kernel\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.1301431047938488,
#   0.05048238208117308,
#   0.038362599378762144,
#   0.031139573705624098,
#   0.028385079864171093,
#   0.023250245129103186,
#   0.0215228461375529],
#  'train_accuracy': [0.961,
#   0.9839074074074075,
#   0.9875185185185186,
#   0.9903333333333333,
#   0.990462962962963,
#   0.9926111111111111,
#   0.9932962962962963],
#  'val_loss': [0.05896595106522242,
#   0.045838438969105486,
#   0.039141871063659586,
#   0.03934400947826604,
#   0.03421914302340398,
#   0.03588700249325484,
#   0.032994956707271435],
#  'val_accuracy': [0.983,
#   0.9861666666666666,
#   0.9895,
#   0.9893333333333333,
#   0.9908333333333333,
#   0.9905,
#   0.9908333333333333],
#  'epoch_duration_seconds': [7.913811700000224,
#   8.065374099998735,
#   8.105815500002791,
#   7.714640099999087,
#   8.048854600001505,
#   7.893450399998983,
#   7.940379399999074]}
