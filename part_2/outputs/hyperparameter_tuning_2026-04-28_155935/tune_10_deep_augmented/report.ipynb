# %% [markdown]
# # Experiment Report
#
# Run folder: `tune_10_deep_augmented`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\hyperparameter_tuning_2026-04-28_155935\tune_10_deep_augmented")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: tune_10_deep_augmented

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.0007,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0002,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.03,
#  'augmentation_enabled': True,
#  'augmentation_description': 'rotation_degrees=12.0, translate=(0.1, 0.1), scale=(0.9, 1.1)',
#  'augmentation_config': {'enabled': True,
#   'rotation_degrees': 12.0,
#   'translate': [0.1, 0.1],
#   'scale': [0.9, 1.1]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_10_deep_augmented',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_regularized',
#  'conv_channels': [32, 64, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 256,
#  'activation': 'ReLU',
#  'dropout': 0.25,
#  'batch_norm': True,
#  'trainable_parameters': 206346,
#  'num_conv_layers': 3}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 7,
#  'best_validation_loss': 0.026707100399769843,
#  'best_validation_accuracy': 0.9923333333333333,
#  'time_to_best_model_seconds': 77.78610320000007,
#  'total_training_time_seconds': 79.12939030000052,
#  'average_epoch_time_seconds': 11.099082142856787,
#  'final_test_loss': 0.020960799460334238,
#  'final_test_accuracy': 0.993,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_10_deep_augmented\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.22999807856369903,
#   0.08882187002786883,
#   0.07181113270766758,
#   0.06287722879206693,
#   0.05547409667323033,
#   0.052247435028630274,
#   0.04811833812765501],
#  'train_accuracy': [0.9296481481481481,
#   0.9725555555555555,
#   0.9782407407407407,
#   0.9808888888888889,
#   0.9823888888888889,
#   0.9834814814814815,
#   0.9852407407407408],
#  'val_loss': [0.04759657460699479,
#   0.05276997338980436,
#   0.03797898728835086,
#   0.03553516803433498,
#   0.03301584176843365,
#   0.031875719954259696,
#   0.026707100399769843],
#  'val_accuracy': [0.986,
#   0.9836666666666667,
#   0.9881666666666666,
#   0.9903333333333333,
#   0.9893333333333333,
#   0.9895,
#   0.9923333333333333],
#  'epoch_duration_seconds': [11.353085900002043,
#   11.188941799999157,
#   10.978960699998424,
#   10.980517799998779,
#   11.001550000000861,
#   10.889854599998216,
#   11.300664200000028]}
