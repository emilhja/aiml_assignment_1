# %% [markdown]
# # Experiment Report
#
# Run folder: `tune_16_adam_beta_variant`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\hyperparameter_tuning_2026-04-28_155935\tune_16_adam_beta_variant")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: tune_16_adam_beta_variant

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0001,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.85,
#  'adam_beta2': 0.995,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_16_adam_beta_variant',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_batchnorm',
#  'conv_channels': [32, 64, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 256,
#  'activation': 'ReLU',
#  'dropout': 0.1,
#  'batch_norm': True,
#  'trainable_parameters': 206346,
#  'num_conv_layers': 3}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 7,
#  'best_validation_loss': 0.03163273110946951,
#  'best_validation_accuracy': 0.9908333333333333,
#  'time_to_best_model_seconds': 61.14007219999985,
#  'total_training_time_seconds': 62.70528109999941,
#  'average_epoch_time_seconds': 8.720396971429311,
#  'final_test_loss': 0.030240654030031875,
#  'final_test_accuracy': 0.9908,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_16_adam_beta_variant\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.11351153607224977,
#   0.0441616915098081,
#   0.0326815173936042,
#   0.02593840044040095,
#   0.0220995734315538,
#   0.017654103782860114,
#   0.016201759949636955],
#  'train_accuracy': [0.9658888888888889,
#   0.9863148148148149,
#   0.9897222222222222,
#   0.9918518518518519,
#   0.9930555555555556,
#   0.9942222222222222,
#   0.9946481481481482],
#  'val_loss': [0.05683076518774033,
#   0.04550873682151238,
#   0.04480594728638729,
#   0.038470211448768776,
#   0.03458003692701459,
#   0.035200605898629875,
#   0.03163273110946951],
#  'val_accuracy': [0.984,
#   0.987,
#   0.9866666666666667,
#   0.9896666666666667,
#   0.9906666666666667,
#   0.9886666666666667,
#   0.9908333333333333],
#  'epoch_duration_seconds': [8.687604800001282,
#   9.12110489999759,
#   8.57548769999994,
#   8.51919750000161,
#   8.622345200001291,
#   8.589147800001228,
#   8.92789090000224]}
