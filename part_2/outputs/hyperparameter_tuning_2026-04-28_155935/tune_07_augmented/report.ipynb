# %% [markdown]
# # Experiment Report
#
# Run folder: `tune_07_augmented`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\hyperparameter_tuning_2026-04-28_155935\tune_07_augmented")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: tune_07_augmented

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0001,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': True,
#  'augmentation_description': 'rotation_degrees=10.0, translate=(0.1, 0.1), scale=(0.95, 1.05)',
#  'augmentation_config': {'enabled': True,
#   'rotation_degrees': 10.0,
#   'translate': [0.1, 0.1],
#   'scale': [0.95, 1.05]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_07_augmented',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_batchnorm',
#  'conv_channels': [32, 64, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 256,
#  'activation': 'ReLU',
#  'dropout': 0.1,
#  'batch_norm': True,
#  'trainable_parameters': 206346,
#  'num_conv_layers': 3}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 5,
#  'best_validation_loss': 0.026643702525800714,
#  'best_validation_accuracy': 0.9915,
#  'time_to_best_model_seconds': 60.01889260000098,
#  'total_training_time_seconds': 84.90382129999853,
#  'average_epoch_time_seconds': 11.913354014287117,
#  'final_test_loss': 0.020839884230413008,
#  'final_test_accuracy': 0.9939,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_07_augmented\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.18942392947000486,
#   0.07511035972474901,
#   0.05972028550084818,
#   0.05175291347062146,
#   0.04701262412613465,
#   0.04329701640450016,
#   0.04000115118548274],
#  'train_accuracy': [0.9420925925925926,
#   0.9763888888888889,
#   0.9810925925925926,
#   0.9844074074074074,
#   0.9851666666666666,
#   0.9859259259259259,
#   0.9872407407407408],
#  'val_loss': [0.05642289393146833,
#   0.04786759278054039,
#   0.04789759442086021,
#   0.038440889569620294,
#   0.026643702525800714,
#   0.033033528338186444,
#   0.03072877248430935],
#  'val_accuracy': [0.9826666666666667,
#   0.9845,
#   0.9858333333333333,
#   0.9891666666666666,
#   0.9915,
#   0.9886666666666667,
#   0.9903333333333333],
#  'epoch_duration_seconds': [12.033765800002584,
#   11.900336900002003,
#   11.77487470000051,
#   12.817949700001918,
#   11.435834000003524,
#   11.460259999999835,
#   11.970456999999442]}
