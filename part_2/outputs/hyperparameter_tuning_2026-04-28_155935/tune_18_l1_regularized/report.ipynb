# %% [markdown]
# # Experiment Report
#
# Run folder: `tune_18_l1_regularized`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\hyperparameter_tuning_2026-04-28_155935\tune_18_l1_regularized")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: tune_18_l1_regularized

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0,
#  'l1_lambda': 1e-06,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_18_l1_regularized',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_batchnorm',
#  'conv_channels': [32, 64, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 256,
#  'activation': 'ReLU',
#  'dropout': 0.1,
#  'batch_norm': True,
#  'trainable_parameters': 206346,
#  'num_conv_layers': 3}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 7,
#  'best_validation_loss': 0.03124529192103849,
#  'best_validation_accuracy': 0.991,
#  'time_to_best_model_seconds': 69.4083137000016,
#  'total_training_time_seconds': 70.74351949999982,
#  'average_epoch_time_seconds': 9.905110099999936,
#  'final_test_loss': 0.03035996981895805,
#  'final_test_accuracy': 0.9905,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\hyperparameter_tuning_2026-04-28_155935\\tune_18_l1_regularized\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.1166394126172419,
#   0.046457737892866134,
#   0.03660644081869611,
#   0.031082958848388107,
#   0.027339622577169428,
#   0.02366379272799801,
#   0.022134398587324],
#  'train_accuracy': [0.9667407407407408,
#   0.9877222222222222,
#   0.9897777777777778,
#   0.9921481481481481,
#   0.9932962962962963,
#   0.994574074074074,
#   0.9952407407407408],
#  'val_loss': [0.04846293041358391,
#   0.05861079880098502,
#   0.04595326284288118,
#   0.04815974141781529,
#   0.04708130943061163,
#   0.03912967745432009,
#   0.03124529192103849],
#  'val_accuracy': [0.9863333333333333,
#   0.9826666666666667,
#   0.9875,
#   0.9865,
#   0.9886666666666667,
#   0.9893333333333333,
#   0.991],
#  'epoch_duration_seconds': [9.913263900001766,
#   9.752609099999972,
#   9.85067060000074,
#   9.86059430000023,
#   10.15945510000165,
#   9.937212899996666,
#   9.861964799998532]}
