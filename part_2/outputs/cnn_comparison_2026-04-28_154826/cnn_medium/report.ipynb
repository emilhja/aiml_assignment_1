# %% [markdown]
# # Experiment Report
#
# Run folder: `cnn_medium`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\cnn_comparison_2026-04-28_154826\cnn_medium")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: cnn_medium

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 5,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\cnn_comparison_2026-04-28_154826\\cnn_medium',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_medium',
#  'conv_channels': [32, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 128,
#  'activation': 'LeakyReLU',
#  'dropout': 0.0,
#  'batch_norm': False,
#  'trainable_parameters': 421642,
#  'num_conv_layers': 2}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 4,
#  'best_validation_loss': 0.03860566270103057,
#  'best_validation_accuracy': 0.9886666666666667,
#  'time_to_best_model_seconds': 28.081057900002634,
#  'total_training_time_seconds': 36.361532400002034,
#  'average_epoch_time_seconds': 7.005485220000264,
#  'final_test_loss': 0.03004389261924662,
#  'final_test_accuracy': 0.9911,
#  'stopped_early': False,
#  'epochs_completed': 5,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\cnn_comparison_2026-04-28_154826\\cnn_medium\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.16316346795856954,
#   0.043436373733880894,
#   0.029540290478858408,
#   0.020796517625692543,
#   0.015504053930545018],
#  'train_accuracy': [0.9505185185185185,
#   0.987037037037037,
#   0.9908703703703704,
#   0.993574074074074,
#   0.9948888888888889],
#  'val_loss': [0.05919744589428107,
#   0.05163032831251621,
#   0.05001413916423917,
#   0.03860566270103057,
#   0.045169013319537044],
#  'val_accuracy': [0.9831666666666666,
#   0.9851666666666666,
#   0.9838333333333333,
#   0.9886666666666667,
#   0.9876666666666667],
#  'epoch_duration_seconds': [7.070868500002689,
#   6.979215100000147,
#   6.9940662999979395,
#   6.986544900002627,
#   6.9967312999979185]}
