# %% [markdown]
# # Experiment Report
#
# Run folder: `with_augmentation`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\augmentation_comparison_2026-04-28_154632\with_augmentation")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: with_augmentation

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 5,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': True,
#  'augmentation_description': 'rotation_degrees=10.0, translate=(0.1, 0.1), scale=(0.95, 1.05)',
#  'augmentation_config': {'enabled': True,
#   'rotation_degrees': 10.0,
#   'translate': [0.1, 0.1],
#   'scale': [0.95, 1.05]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\augmentation_comparison_2026-04-28_154632\\with_augmentation',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_medium',
#  'conv_channels': [32, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 128,
#  'activation': 'LeakyReLU',
#  'dropout': 0.0,
#  'batch_norm': False,
#  'trainable_parameters': 421642,
#  'num_conv_layers': 2}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 4,
#  'best_validation_loss': 0.028835717453931767,
#  'best_validation_accuracy': 0.9908333333333333,
#  'time_to_best_model_seconds': 40.40781249999782,
#  'total_training_time_seconds': 51.49381709999943,
#  'average_epoch_time_seconds': 10.039363219999359,
#  'final_test_loss': 0.023584913424064873,
#  'final_test_accuracy': 0.9923,
#  'stopped_early': False,
#  'epochs_completed': 5,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\augmentation_comparison_2026-04-28_154632\\with_augmentation\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.30698274629204364,
#   0.09113090772098965,
#   0.0702249943393248,
#   0.0567533833000257,
#   0.049936980762967355],
#  'train_accuracy': [0.9016296296296297,
#   0.9710740740740741,
#   0.977462962962963,
#   0.9822037037037037,
#   0.984037037037037],
#  'val_loss': [0.07364837400615215,
#   0.0470340631082654,
#   0.04466196941708525,
#   0.028835717453931767,
#   0.034361994607374075],
#  'val_accuracy': [0.9775,
#   0.9846666666666667,
#   0.987,
#   0.9908333333333333,
#   0.989],
#  'epoch_duration_seconds': [10.569414400000824,
#   10.02167709999776,
#   9.870304000000033,
#   9.897355599998264,
#   9.838064999999915]}
