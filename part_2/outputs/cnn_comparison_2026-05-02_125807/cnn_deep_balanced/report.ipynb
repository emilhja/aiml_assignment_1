# %% [markdown]
# # Experiment Report
#
# Run folder: `cnn_deep_balanced`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\cnn_comparison_2026-05-02_125807\cnn_deep_balanced")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: cnn_deep_balanced

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 25,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\cnn_comparison_2026-05-02_125807\\cnn_deep_balanced',
#  'git_commit': '31cc8433263ee46cd95793866bb2a6d98c8a0fbf',
#  'git_is_dirty': True,
#  'model_name': 'cnn_deep_balanced',
#  'conv_channels': [32, 64, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 512,
#  'activation': 'ReLU',
#  'dropout': 0.0,
#  'batch_norm': False,
#  'trainable_parameters': 356298,
#  'num_conv_layers': 3}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 4,
#  'best_validation_loss': 0.03245383699486653,
#  'best_validation_accuracy': 0.9898333333333333,
#  'time_to_best_model_seconds': 32.967150100000254,
#  'total_training_time_seconds': 75.47351590000017,
#  'average_epoch_time_seconds': 8.21902352222211,
#  'final_test_loss': 0.025434837377769873,
#  'final_test_accuracy': 0.9912,
#  'stopped_early': True,
#  'epochs_completed': 9,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\cnn_comparison_2026-05-02_125807\\cnn_deep_balanced\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.18056087368919893,
#   0.04866353425618123,
#   0.03428497233769546,
#   0.02655306053156447,
#   0.02192702385514147,
#   0.018549342372862158,
#   0.01480587165816299,
#   0.014863374264092677,
#   0.011957425408341266],
#  'train_accuracy': [0.9427777777777778,
#   0.9849814814814815,
#   0.9891851851851852,
#   0.9916111111111111,
#   0.9927037037037038,
#   0.9938518518518519,
#   0.9950740740740741,
#   0.995537037037037,
#   0.9961111111111111],
#  'val_loss': [0.07832737092177074,
#   0.04981762903183699,
#   0.047230184689164165,
#   0.03245383699486653,
#   0.09606628748774529,
#   0.053080992774805054,
#   0.04032164440785224,
#   0.03503367088096759,
#   0.03307751688322363],
#  'val_accuracy': [0.9746666666666667,
#   0.9845,
#   0.9871666666666666,
#   0.9898333333333333,
#   0.9753333333333334,
#   0.9871666666666666,
#   0.9908333333333333,
#   0.9916666666666667,
#   0.9918333333333333],
#  'epoch_duration_seconds': [7.931242099999508,
#   8.599189200000183,
#   8.103302399999848,
#   8.283097300000009,
#   8.379399900000863,
#   8.582854899999802,
#   7.8306245999992825,
#   8.264229499999601,
#   7.997271799999908]}
