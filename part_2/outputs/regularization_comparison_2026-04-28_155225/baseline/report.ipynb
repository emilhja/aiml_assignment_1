# %% [markdown]
# # Experiment Report
#
# Run folder: `baseline`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\regularization_comparison_2026-04-28_155225\baseline")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: baseline

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\regularization_comparison_2026-04-28_155225\\baseline',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_medium',
#  'conv_channels': [32, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 128,
#  'activation': 'LeakyReLU',
#  'dropout': 0.0,
#  'batch_norm': False,
#  'trainable_parameters': 421642,
#  'num_conv_layers': 2}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 6,
#  'best_validation_loss': 0.0350444634432594,
#  'best_validation_accuracy': 0.9903333333333333,
#  'time_to_best_model_seconds': 44.17833810000229,
#  'total_training_time_seconds': 52.88391770000089,
#  'average_epoch_time_seconds': 7.337174199999156,
#  'final_test_loss': 0.026716402003829718,
#  'final_test_accuracy': 0.9909,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\regularization_comparison_2026-04-28_155225\\baseline\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.16329135963320732,
#   0.04388086936843616,
#   0.029503250513156807,
#   0.02118156866080783,
#   0.015440658047950516,
#   0.013256062087128628,
#   0.010648753598378217],
#  'train_accuracy': [0.9500555555555555,
#   0.9867777777777778,
#   0.9907222222222222,
#   0.9932407407407408,
#   0.9952592592592593,
#   0.9955925925925926,
#   0.9965185185185185],
#  'val_loss': [0.05917026136815548,
#   0.05285120366513729,
#   0.052604874834418294,
#   0.03679873987659812,
#   0.04060570763175686,
#   0.0350444634432594,
#   0.04948785612320838],
#  'val_accuracy': [0.9831666666666666,
#   0.9846666666666667,
#   0.9828333333333333,
#   0.9883333333333333,
#   0.9878333333333333,
#   0.9903333333333333,
#   0.988],
#  'epoch_duration_seconds': [7.513549699997384,
#   7.400625999998738,
#   7.09854759999871,
#   7.314105699999345,
#   7.530538400002115,
#   7.2395051999992575,
#   7.263346799998544]}
