# %% [markdown]
# # Experiment Report
#
# Run folder: `dropout_only`
#
# This notebook reproduces the configuration and inspects the saved artifacts for this experiment.

# %%
import sys
from pathlib import Path
import json
import matplotlib.pyplot as plt
from IPython.display import Image, display

PROJECT_ROOT = Path(r"C:\Users\emil_\vscode\Assignment1")
RUN_DIR = Path(r"C:\Users\emil_\vscode\Assignment1\part_2\outputs\regularization_comparison_2026-04-28_155225\dropout_only")
CONFIG_PATH = RUN_DIR / "config.json"
SUMMARY_PATH = RUN_DIR / "summary.json"
HISTORY_PATH = RUN_DIR / "training_history.json"

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

config = json.loads(CONFIG_PATH.read_text(encoding="utf-8"))
summary = json.loads(SUMMARY_PATH.read_text(encoding="utf-8"))
history = json.loads(HISTORY_PATH.read_text(encoding="utf-8"))
print(f"Loaded run: {RUN_DIR.name}")
# Out:
# Loaded run: dropout_only

# %% [markdown]
# ## Training Config

# %%
config
# Out:
# {'batch_size': 64,
#  'epochs': 7,
#  'learning_rate': 0.001,
#  'checkpoint_interval': 5,
#  'validation_ratio': 0.1,
#  'seed': 42,
#  'early_stopping_patience': 5,
#  'optimizer_name': 'Adam',
#  'weight_decay': 0.0,
#  'l1_lambda': 0.0,
#  'adam_beta1': 0.9,
#  'adam_beta2': 0.999,
#  'adam_eps': 1e-08,
#  'input_noise_std': 0.0,
#  'augmentation_enabled': False,
#  'augmentation_description': 'rotation_degrees=0.0, translate=(0.0, 0.0), scale=(1.0, 1.0)',
#  'augmentation_config': {'enabled': False,
#   'rotation_degrees': 0.0,
#   'translate': [0.0, 0.0],
#   'scale': [1.0, 1.0]},
#  'device': 'cuda:0',
#  'output_dir': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\regularization_comparison_2026-04-28_155225\\dropout_only',
#  'git_commit': '2d0d359a3a26e3347c5c54a75b9cabcd48c9e841',
#  'git_is_dirty': True,
#  'model_name': 'cnn_dropout',
#  'conv_channels': [32, 64],
#  'kernel_size': 3,
#  'pool_kernel_size': 2,
#  'classifier_hidden_size': 128,
#  'activation': 'ReLU',
#  'dropout': 0.3,
#  'batch_norm': False,
#  'trainable_parameters': 421642,
#  'num_conv_layers': 2}

# %% [markdown]
# ## Final Summary

# %%
summary
# Out:
# {'best_epoch': 4,
#  'best_validation_loss': 0.03634824275442709,
#  'best_validation_accuracy': 0.9901666666666666,
#  'time_to_best_model_seconds': 32.1164303000005,
#  'total_training_time_seconds': 58.019742500000575,
#  'average_epoch_time_seconds': 8.082089300000266,
#  'final_test_loss': 0.023556575211253948,
#  'final_test_accuracy': 0.9921,
#  'stopped_early': False,
#  'epochs_completed': 7,
#  'best_model_path': 'C:\\Users\\emil_\\vscode\\Assignment1\\part_2\\outputs\\regularization_comparison_2026-04-28_155225\\dropout_only\\best_model.pt'}

# %% [markdown]
# ## Re-run This Experiment

# %%
from part_2.main import run_experiment

# Uncomment to re-run this exact experiment into a separate folder.
# rerun_output_dir = RUN_DIR.parent / f"{RUN_DIR.name}_rerun"
# run_experiment(
#     batch_size=config['batch_size'],
#     epochs=config['epochs'],
#     learning_rate=config['learning_rate'],
#     output_dir=rerun_output_dir,
#     checkpoint_interval=config['checkpoint_interval'],
#     validation_ratio=config['validation_ratio'],
#     seed=config['seed'],
#     early_stopping_patience=config['early_stopping_patience'],
#     augmentation_config=config.get('augmentation_config'),
# )

# %% [markdown]
# ## Saved Plots

# %%
plot_files = [
    'loss_curve.png',
    'accuracy_curve.png',
    'correct_predictions.png',
    'incorrect_predictions.png',
    'confusion_matrix.png',
    'conv_filters_first.png',
    'conv_filters_last.png',
]
for plot_name in plot_files:
    plot_path = RUN_DIR / plot_name
    print(f'\n### {plot_name}')
    if plot_path.exists():
        display(Image(filename=str(plot_path)))
    else:
        print('Missing:', plot_path)
# Out:
# ### loss_curve.png
# ### accuracy_curve.png
# ### correct_predictions.png
# ### incorrect_predictions.png
# ### confusion_matrix.png
# ### conv_filters_first.png
# ### conv_filters_last.png

# %% [markdown]
# ## Training History

# %%
history
# Out:
# {'train_loss': [0.24115988103493496,
#   0.07277591495795382,
#   0.052019723034567304,
#   0.043052978272515315,
#   0.03468466883294146,
#   0.029215574636417267,
#   0.024425258437275058],
#  'train_accuracy': [0.9240925925925926,
#   0.9783148148148149,
#   0.9843703703703703,
#   0.9866851851851852,
#   0.9892222222222222,
#   0.9907037037037038,
#   0.9924259259259259],
#  'val_loss': [0.0614913322130839,
#   0.0560622176527977,
#   0.05560174688448508,
#   0.03634824275442709,
#   0.04191870051777611,
#   0.039606506467486424,
#   0.03833865142194554],
#  'val_accuracy': [0.9826666666666667,
#   0.984,
#   0.984,
#   0.9901666666666666,
#   0.9876666666666667,
#   0.9883333333333333,
#   0.9903333333333333],
#  'epoch_duration_seconds': [7.719730200002232,
#   8.587064499999542,
#   8.172524699999485,
#   7.584071600002062,
#   8.291257400000177,
#   8.442736699998932,
#   7.777239999999438]}
